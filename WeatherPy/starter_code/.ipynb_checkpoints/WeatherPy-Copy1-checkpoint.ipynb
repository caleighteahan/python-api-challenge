# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units= "metric"

# Define an empty list to fetch the weather data for each city
query_url = f"{url}appid={weather_api_key}&units={units}&q="

city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i,city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city 
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather =requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather["clouds"]['all']
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | taunsa
# Processing Record 6 of Set 1 | sitka
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | pacific grove
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | bilibino
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | quatre cocos
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | kudahuvadhoo
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | lihue
# Processing Record 17 of Set 1 | isafjordur
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | whitehorse
# Processing Record 20 of Set 1 | queenstown
# Processing Record 21 of Set 1 | ust-nera
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | brookings
# Processing Record 24 of Set 1 | ta`u
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | aginskoye
# Processing Record 27 of Set 1 | al-`ula
# City not found. Skipping...
# Processing Record 28 of Set 1 | loreto
# Processing Record 29 of Set 1 | cay
# Processing Record 30 of Set 1 | invercargill
# Processing Record 31 of Set 1 | klyuchi
# Processing Record 32 of Set 1 | saipan
# Processing Record 33 of Set 1 | north bend
# Processing Record 34 of Set 1 | adamstown
# Processing Record 35 of Set 1 | kovdor
# Processing Record 36 of Set 1 | la gi
# Processing Record 37 of Set 1 | anadyr
# Processing Record 38 of Set 1 | hamilton
# Processing Record 39 of Set 1 | governor's harbour
# City not found. Skipping...
# Processing Record 40 of Set 1 | olonkinbyen
# Processing Record 41 of Set 1 | pochinki
# Processing Record 42 of Set 1 | magadan
# Processing Record 43 of Set 1 | margaret river
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | padang
# Processing Record 46 of Set 1 | sciacca
# Processing Record 47 of Set 1 | puerto natales
# Processing Record 48 of Set 1 | nyurba
# Processing Record 49 of Set 1 | wenshui
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 0 of Set 2 | tahla
# Processing Record 1 of Set 2 | tebessa
# Processing Record 2 of Set 2 | colonia
# Processing Record 3 of Set 2 | okondja
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | zeya
# Processing Record 6 of Set 2 | cambria
# Processing Record 7 of Set 2 | maridi
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | nar'yan-mar
# Processing Record 10 of Set 2 | basco
# Processing Record 11 of Set 2 | richards bay
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 14 of Set 2 | cockburn town
# Processing Record 15 of Set 2 | petal
# Processing Record 16 of Set 2 | lurugan
# Processing Record 17 of Set 2 | mbanza-ngungu
# Processing Record 18 of Set 2 | manismata
# Processing Record 19 of Set 2 | joshua tree
# Processing Record 20 of Set 2 | chonchi
# Processing Record 21 of Set 2 | wailua homesteads
# Processing Record 22 of Set 2 | rongelap
# Processing Record 23 of Set 2 | hawaiian paradise park
# Processing Record 24 of Set 2 | adrar
# Processing Record 25 of Set 2 | djibo
# Processing Record 26 of Set 2 | kavieng
# Processing Record 27 of Set 2 | enewetak
# Processing Record 28 of Set 2 | nantucket
# Processing Record 29 of Set 2 | kerikeri
# Processing Record 30 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | mancora
# Processing Record 33 of Set 2 | lashio
# Processing Record 34 of Set 2 | stanley
# Processing Record 35 of Set 2 | aasiaat
# Processing Record 36 of Set 2 | liberia
# Processing Record 37 of Set 2 | la sarre
# Processing Record 38 of Set 2 | tura
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | nguigmi
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | sonsorol village
# City not found. Skipping...
# Processing Record 43 of Set 2 | hadibu
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | san patricio
# Processing Record 46 of Set 2 | gebeit
# Processing Record 47 of Set 2 | kaka
# Processing Record 48 of Set 2 | udachny
# Processing Record 49 of Set 2 | tual
# Processing Record 0 of Set 3 | chillicothe
# Processing Record 1 of Set 3 | bayanhongor
# Processing Record 2 of Set 3 | kourou
# Processing Record 3 of Set 3 | nuuk
# Processing Record 4 of Set 3 | punta arenas
# Processing Record 5 of Set 3 | kailua-kona
# Processing Record 6 of Set 3 | vila franca do campo
# Processing Record 7 of Set 3 | ponta delgada
# Processing Record 8 of Set 3 | goure
# Processing Record 9 of Set 3 | nova sintra
# Processing Record 10 of Set 3 | akcadag
# Processing Record 11 of Set 3 | mount isa
# Processing Record 12 of Set 3 | mar del plata
# Processing Record 13 of Set 3 | qaqortoq
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | turpan
# Processing Record 16 of Set 3 | papatowai
# Processing Record 17 of Set 3 | vila do maio
# Processing Record 18 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 19 of Set 3 | ekpoma
# Processing Record 20 of Set 3 | oranjemund
# Processing Record 21 of Set 3 | muzayri'
# City not found. Skipping...
# Processing Record 22 of Set 3 | belyy yar
# Processing Record 23 of Set 3 | mont-dore
# Processing Record 24 of Set 3 | parnu
# Processing Record 25 of Set 3 | altamont
# Processing Record 26 of Set 3 | malango
# Processing Record 27 of Set 3 | jaisalmer
# Processing Record 28 of Set 3 | tolanaro
# Processing Record 29 of Set 3 | san luis de la loma
# Processing Record 30 of Set 3 | jamestown
# Processing Record 31 of Set 3 | hafnarfjordur
# Processing Record 32 of Set 3 | holualoa
# Processing Record 33 of Set 3 | blackmans bay
# Processing Record 34 of Set 3 | bandar lampung
# Processing Record 35 of Set 3 | san antonio de pale
# Processing Record 36 of Set 3 | kill devil hills
# Processing Record 37 of Set 3 | sorong
# Processing Record 38 of Set 3 | namibe
# Processing Record 39 of Set 3 | susuman
# Processing Record 40 of Set 3 | afaahiti
# Processing Record 41 of Set 3 | yaren
# Processing Record 42 of Set 3 | alaghsas
# Processing Record 43 of Set 3 | sima
# Processing Record 44 of Set 3 | klaksvik
# Processing Record 45 of Set 3 | bargaal
# Processing Record 46 of Set 3 | kapa'a
# Processing Record 47 of Set 3 | santa pola
# Processing Record 48 of Set 3 | al hudaydah
# Processing Record 49 of Set 3 | flying fish cove
# Processing Record 0 of Set 4 | port saint john's
# Processing Record 1 of Set 4 | tadine
# Processing Record 2 of Set 4 | kirovskiy
# Processing Record 3 of Set 4 | matoury
# Processing Record 4 of Set 4 | talnakh
# Processing Record 5 of Set 4 | onega
# Processing Record 6 of Set 4 | sabzevar
# Processing Record 7 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 8 of Set 4 | harper
# Processing Record 9 of Set 4 | st. john's
# Processing Record 10 of Set 4 | porto novo
# Processing Record 11 of Set 4 | fort bragg
# Processing Record 12 of Set 4 | chaman
# Processing Record 13 of Set 4 | maloye ganyushkino
# Processing Record 14 of Set 4 | puerto baquerizo moreno
# Processing Record 15 of Set 4 | christchurch
# Processing Record 16 of Set 4 | nuku'alofa
# Processing Record 17 of Set 4 | remire-montjoly
# Processing Record 18 of Set 4 | kargil
# Processing Record 19 of Set 4 | vytegra
# Processing Record 20 of Set 4 | puerto ayora
# Processing Record 21 of Set 4 | rawson
# Processing Record 22 of Set 4 | balakhta
# Processing Record 23 of Set 4 | rouissat
# Processing Record 24 of Set 4 | les avirons
# Processing Record 25 of Set 4 | haiku-pauwela
# Processing Record 26 of Set 4 | taksimo
# Processing Record 27 of Set 4 | farah
# Processing Record 28 of Set 4 | ivdel'
# Processing Record 29 of Set 4 | saudarkrokur
# Processing Record 30 of Set 4 | pangody
# Processing Record 31 of Set 4 | bubaque
# Processing Record 32 of Set 4 | chibougamau
# Processing Record 33 of Set 4 | embarcacion
# Processing Record 34 of Set 4 | san pedro pochutla
# Processing Record 35 of Set 4 | polovinnoye
# Processing Record 36 of Set 4 | alice springs
# Processing Record 37 of Set 4 | olinda
# Processing Record 38 of Set 4 | isangel
# Processing Record 39 of Set 4 | prado
# Processing Record 40 of Set 4 | praia da vitoria
# Processing Record 41 of Set 4 | utrik
# Processing Record 42 of Set 4 | midvagur
# Processing Record 43 of Set 4 | tobelo
# Processing Record 44 of Set 4 | wukari
# Processing Record 45 of Set 4 | bonthe
# Processing Record 46 of Set 4 | kangaba
# Processing Record 47 of Set 4 | as sulayyil
# Processing Record 48 of Set 4 | tiksi
# Processing Record 49 of Set 4 | espiye
# Processing Record 0 of Set 5 | bathsheba
# Processing Record 1 of Set 5 | isla mujeres
# Processing Record 2 of Set 5 | atafu village
# Processing Record 3 of Set 5 | badger
# Processing Record 4 of Set 5 | dudinka
# Processing Record 5 of Set 5 | palmer
# Processing Record 6 of Set 5 | smithers
# Processing Record 7 of Set 5 | lodwar
# Processing Record 8 of Set 5 | livingstonia
# Processing Record 9 of Set 5 | adelaide
# Processing Record 10 of Set 5 | leava
# Processing Record 11 of Set 5 | la'ie
# Processing Record 12 of Set 5 | north ward
# Processing Record 13 of Set 5 | xinqing
# Processing Record 14 of Set 5 | lethem
# Processing Record 15 of Set 5 | fort wellington
# Processing Record 16 of Set 5 | ayutla de los libres
# Processing Record 17 of Set 5 | naze
# Processing Record 18 of Set 5 | port mathurin
# Processing Record 19 of Set 5 | leh
# Processing Record 20 of Set 5 | atuncolla
# Processing Record 21 of Set 5 | ha tinh
# Processing Record 22 of Set 5 | amos
# Processing Record 23 of Set 5 | isle of lewis
# City not found. Skipping...
# Processing Record 24 of Set 5 | bol'shoy kamen'
# Processing Record 25 of Set 5 | samana
# Processing Record 26 of Set 5 | codrington
# Processing Record 27 of Set 5 | puerto ayacucho
# Processing Record 28 of Set 5 | magistral'nyy
# Processing Record 29 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 30 of Set 5 | lee acres
# Processing Record 31 of Set 5 | antsiranana
# Processing Record 32 of Set 5 | ceelbuur
# Processing Record 33 of Set 5 | kamina
# Processing Record 34 of Set 5 | katsuura
# Processing Record 35 of Set 5 | am djarass
# City not found. Skipping...
# Processing Record 36 of Set 5 | kita
# Processing Record 37 of Set 5 | itaituba
# Processing Record 38 of Set 5 | kaoma
# Processing Record 39 of Set 5 | catacaos
# Processing Record 40 of Set 5 | bela
# Processing Record 41 of Set 5 | west island
# Processing Record 42 of Set 5 | weno
# Processing Record 43 of Set 5 | ellsworth
# Processing Record 44 of Set 5 | durres
# Processing Record 45 of Set 5 | shingu
# Processing Record 46 of Set 5 | mooloolaba
# Processing Record 47 of Set 5 | new norfolk
# Processing Record 48 of Set 5 | crucecita
# Processing Record 49 of Set 5 | jatai
# Processing Record 0 of Set 6 | cooper's town
# Processing Record 1 of Set 6 | talikota
# Processing Record 2 of Set 6 | vorgashor
# Processing Record 3 of Set 6 | alofi
# Processing Record 4 of Set 6 | coquimbo
# Processing Record 5 of Set 6 | pemangkat
# Processing Record 6 of Set 6 | nema
# Processing Record 7 of Set 6 | idri
# Processing Record 8 of Set 6 | mae hong son
# Processing Record 9 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 10 of Set 6 | auki
# Processing Record 11 of Set 6 | tsiombe
# Processing Record 12 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 13 of Set 6 | matthew town
# Processing Record 14 of Set 6 | pitanga
# Processing Record 15 of Set 6 | mil'kovo
# Processing Record 16 of Set 6 | saldanha
# Processing Record 17 of Set 6 | nagqu
# Processing Record 18 of Set 6 | chetwayi
# Processing Record 19 of Set 6 | kavaratti
# Processing Record 20 of Set 6 | conduaga
# Processing Record 21 of Set 6 | west end
# Processing Record 22 of Set 6 | mwinilunga
# Processing Record 23 of Set 6 | samborondon
# Processing Record 24 of Set 6 | barcin
# Processing Record 25 of Set 6 | portland
# Processing Record 26 of Set 6 | nemuro
# Processing Record 27 of Set 6 | eilat
# Processing Record 28 of Set 6 | northam
# Processing Record 29 of Set 6 | bintulu
# Processing Record 30 of Set 6 | bardai
# Processing Record 31 of Set 6 | pingdu
# Processing Record 32 of Set 6 | gufeng
# Processing Record 33 of Set 6 | chios
# Processing Record 34 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 6 | puerto deseado
# Processing Record 36 of Set 6 | hithadhoo
# Processing Record 37 of Set 6 | bikenibeu village
# Processing Record 38 of Set 6 | shiyan
# Processing Record 39 of Set 6 | harar
# Processing Record 40 of Set 6 | roma
# Processing Record 41 of Set 6 | port-vila
# Processing Record 42 of Set 6 | baxter
# Processing Record 43 of Set 6 | ad-damazin
# Processing Record 44 of Set 6 | ambon
# Processing Record 45 of Set 6 | aioun
# Processing Record 46 of Set 6 | aykhal
# Processing Record 47 of Set 6 | port hedland
# Processing Record 48 of Set 6 | port elizabeth
# Processing Record 49 of Set 6 | 'ain benian
# Processing Record 0 of Set 7 | murun-kuren
# Processing Record 1 of Set 7 | cromer
# Processing Record 2 of Set 7 | obo
# Processing Record 3 of Set 7 | kismayo
# Processing Record 4 of Set 7 | santa ana
# Processing Record 5 of Set 7 | durazno
# Processing Record 6 of Set 7 | hermanus
# Processing Record 7 of Set 7 | san nicolas
# Processing Record 8 of Set 7 | thisted
# Processing Record 9 of Set 7 | college
# Processing Record 10 of Set 7 | kruisfontein
# Processing Record 11 of Set 7 | rio grande
# Processing Record 12 of Set 7 | bani suwayf
# Processing Record 13 of Set 7 | tofol
# Processing Record 14 of Set 7 | plettenberg bay
# Processing Record 15 of Set 7 | capim grosso
# Processing Record 16 of Set 7 | bir el djir
# Processing Record 17 of Set 7 | arsen'yev
# Processing Record 18 of Set 7 | bcharre
# Processing Record 19 of Set 7 | stephenville
# Processing Record 20 of Set 7 | saidpur
# Processing Record 21 of Set 7 | lata
# Processing Record 22 of Set 7 | sieradz
# Processing Record 23 of Set 7 | argo
# Processing Record 24 of Set 7 | walvis bay
# Processing Record 25 of Set 7 | saint-pierre
# Processing Record 26 of Set 7 | yokadouma
# Processing Record 27 of Set 7 | kupang
# Processing Record 28 of Set 7 | bao loc
# City not found. Skipping...
# Processing Record 29 of Set 7 | egilsstadir
# Processing Record 30 of Set 7 | letlhakane
# Processing Record 31 of Set 7 | vallenar
# Processing Record 32 of Set 7 | ipora
# Processing Record 33 of Set 7 | berezovyy
# Processing Record 34 of Set 7 | holmsund
# Processing Record 35 of Set 7 | la passe
# Processing Record 36 of Set 7 | myitkyina
# Processing Record 37 of Set 7 | ringas
# Processing Record 38 of Set 7 | lobujya
# Processing Record 39 of Set 7 | bambari
# Processing Record 40 of Set 7 | kidal
# Processing Record 41 of Set 7 | port blair
# Processing Record 42 of Set 7 | clovis
# Processing Record 43 of Set 7 | marsala
# Processing Record 44 of Set 7 | banka
# Processing Record 45 of Set 7 | villa gesell
# Processing Record 46 of Set 7 | karratha
# Processing Record 47 of Set 7 | bentota
# Processing Record 48 of Set 7 | esquel
# Processing Record 49 of Set 7 | fortuna
# Processing Record 0 of Set 8 | ha long
# Processing Record 1 of Set 8 | uturoa
# Processing Record 2 of Set 8 | tucumcari
# Processing Record 3 of Set 8 | oliver
# Processing Record 4 of Set 8 | ho
# City not found. Skipping...
# Processing Record 5 of Set 8 | celestun
# Processing Record 6 of Set 8 | correntina
# Processing Record 7 of Set 8 | blackwater
# Processing Record 8 of Set 8 | liman
# Processing Record 9 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 8 | ushibukamachi
# Processing Record 11 of Set 8 | i-n-salah
# Processing Record 12 of Set 8 | am timan
# Processing Record 13 of Set 8 | arraial do cabo
# Processing Record 14 of Set 8 | krasnyy chikoy
# Processing Record 15 of Set 8 | tamiahua
# Processing Record 16 of Set 8 | pak phanang
# Processing Record 17 of Set 8 | puerto aysen
# Processing Record 18 of Set 8 | newnham
# Processing Record 19 of Set 8 | ar rass
# Processing Record 20 of Set 8 | zheshart
# Processing Record 21 of Set 8 | sena madureira
# Processing Record 22 of Set 8 | alcains
# Processing Record 23 of Set 8 | inari
# Processing Record 24 of Set 8 | iskateley
# Processing Record 25 of Set 8 | kasongo-lunda
# Processing Record 26 of Set 8 | santa cruz
# Processing Record 27 of Set 8 | hobyo
# Processing Record 28 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 29 of Set 8 | san rafael
# Processing Record 30 of Set 8 | la cumbre
# Processing Record 31 of Set 8 | baruun-urt
# Processing Record 32 of Set 8 | eenhana
# Processing Record 33 of Set 8 | nevel'sk
# Processing Record 34 of Set 8 | mutuali
# Processing Record 35 of Set 8 | darwin
# Processing Record 36 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 37 of Set 8 | hafar al-batin
# Processing Record 38 of Set 8 | fort st. john
# Processing Record 39 of Set 8 | kingston
# Processing Record 40 of Set 8 | khandyga
# Processing Record 41 of Set 8 | ulsan
# Processing Record 42 of Set 8 | kununurra
# Processing Record 43 of Set 8 | nattheim
# Processing Record 44 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 45 of Set 8 | emerald
# Processing Record 46 of Set 8 | vilyuchinsk
# Processing Record 47 of Set 8 | anabar
# City not found. Skipping...
# Processing Record 48 of Set 8 | greymouth
# Processing Record 49 of Set 8 | ust'-kut
# Processing Record 0 of Set 9 | usogorsk
# Processing Record 1 of Set 9 | barra do corda
# Processing Record 2 of Set 9 | saint-philippe
# Processing Record 3 of Set 9 | hirara
# Processing Record 4 of Set 9 | el calafate
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | constantia
# Processing Record 7 of Set 9 | vaasa
# Processing Record 8 of Set 9 | bria
# Processing Record 9 of Set 9 | easton
# Processing Record 10 of Set 9 | malabar
# Processing Record 11 of Set 9 | owen sound
# Processing Record 12 of Set 9 | princeville
# Processing Record 13 of Set 9 | petauke
# Processing Record 14 of Set 9 | vila velha
# Processing Record 15 of Set 9 | viedma
# Processing Record 16 of Set 9 | ko pha ngan
# Processing Record 17 of Set 9 | seogwipo
# City not found. Skipping...
# Processing Record 18 of Set 9 | alo
# Processing Record 19 of Set 9 | tomatlan
# Processing Record 20 of Set 9 | caleta de carquin
# Processing Record 21 of Set 9 | east london
# Processing Record 22 of Set 9 | arteche
# Processing Record 23 of Set 9 | okha
# Processing Record 24 of Set 9 | port-gentil
# Processing Record 25 of Set 9 | izhmorskiy
# Processing Record 26 of Set 9 | saint-louis
# Processing Record 27 of Set 9 | vernon
# Processing Record 28 of Set 9 | krasnokamensk
# Processing Record 29 of Set 9 | lillehammer
# Processing Record 30 of Set 9 | spring creek
# Processing Record 31 of Set 9 | papao
# Processing Record 32 of Set 9 | trairi
# Processing Record 33 of Set 9 | berber
# Processing Record 34 of Set 9 | south kingstown
# Processing Record 35 of Set 9 | griffith
# Processing Record 36 of Set 9 | happy valley-goose bay
# Processing Record 37 of Set 9 | constitucion
# Processing Record 38 of Set 9 | altay
# Processing Record 39 of Set 9 | cody
# Processing Record 40 of Set 9 | zahedan
# Processing Record 41 of Set 9 | andovoranto
# Processing Record 42 of Set 9 | paka
# Processing Record 43 of Set 9 | eyl
# Processing Record 44 of Set 9 | yaring
# Processing Record 45 of Set 9 | lae
# Processing Record 46 of Set 9 | vilani
# Processing Record 47 of Set 9 | outjo
# Processing Record 48 of Set 9 | ulsteinvik
# Processing Record 49 of Set 9 | kawthoung
# City not found. Skipping...
# Processing Record 0 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 1 of Set 10 | kangasniemi
# Processing Record 2 of Set 10 | sumbawa besar
# Processing Record 3 of Set 10 | tamanrasset
# Processing Record 4 of Set 10 | leribe
# Processing Record 5 of Set 10 | lingen
# Processing Record 6 of Set 10 | revda
# Processing Record 7 of Set 10 | berbera
# Processing Record 8 of Set 10 | dunedin
# Processing Record 9 of Set 10 | kanodar
# Processing Record 10 of Set 10 | yatou
# Processing Record 11 of Set 10 | kandi
# Processing Record 12 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 13 of Set 10 | puerto escondido
# Processing Record 14 of Set 10 | waingapu
# Processing Record 15 of Set 10 | dwarka
# Processing Record 16 of Set 10 | al ghayzah
# Processing Record 17 of Set 10 | uliastay
# Processing Record 18 of Set 10 | vorkuta
# Processing Record 19 of Set 10 | port augusta
# Processing Record 20 of Set 10 | lompoc
# Processing Record 21 of Set 10 | pala
# Processing Record 22 of Set 10 | lorengau
# Processing Record 23 of Set 10 | burela de cabo
# Processing Record 24 of Set 10 | broken hill
# Processing Record 25 of Set 10 | tralee
# Processing Record 26 of Set 10 | tandalti
# Processing Record 27 of Set 10 | horta
# Processing Record 28 of Set 10 | acarau
# Processing Record 29 of Set 10 | dolneni
# Processing Record 30 of Set 10 | achinsk
# Processing Record 31 of Set 10 | callao
# Processing Record 32 of Set 10 | lospalos
# Processing Record 33 of Set 10 | keflavik
# Processing Record 34 of Set 10 | micheweni
# Processing Record 35 of Set 10 | machico
# Processing Record 36 of Set 10 | colesberg
# Processing Record 37 of Set 10 | guerrero negro
# Processing Record 38 of Set 10 | ha'il
# Processing Record 39 of Set 10 | fairmont
# Processing Record 40 of Set 10 | tenango de las flores
# Processing Record 41 of Set 10 | broome
# Processing Record 42 of Set 10 | santiago de cao
# Processing Record 43 of Set 10 | muroto-misakicho
# Processing Record 44 of Set 10 | katpur
# Processing Record 45 of Set 10 | ebon
# Processing Record 46 of Set 10 | aras-asan
# Processing Record 47 of Set 10 | tulun
# Processing Record 48 of Set 10 | an nuhud
# Processing Record 49 of Set 10 | la foa
# Processing Record 0 of Set 11 | aksu
# Processing Record 1 of Set 11 | sitia
# Processing Record 2 of Set 11 | brokopondo
# Processing Record 3 of Set 11 | staufenberg
# Processing Record 4 of Set 11 | tocopilla
# Processing Record 5 of Set 11 | akhmet'a
# Processing Record 6 of Set 11 | axim
# Processing Record 7 of Set 11 | san ignacio de velasco
# Processing Record 8 of Set 11 | thunder bay
# Processing Record 9 of Set 11 | sao francisco
# Processing Record 10 of Set 11 | burgas
# Processing Record 11 of Set 11 | sinjai
# Processing Record 12 of Set 11 | romorantin-lanthenay
# Processing Record 13 of Set 11 | palangkaraya
# Processing Record 14 of Set 11 | sandnessjoen
# Processing Record 15 of Set 11 | tibro
# Processing Record 16 of Set 11 | severo-yeniseyskiy
# Processing Record 17 of Set 11 | tibati
# Processing Record 18 of Set 11 | masterton
# Processing Record 19 of Set 11 | golfito
# Processing Record 20 of Set 11 | gisborne
# Processing Record 21 of Set 11 | gwanda
# Processing Record 22 of Set 11 | gaspe
# Processing Record 23 of Set 11 | chinchilla
# Processing Record 24 of Set 11 | derzhavinsk
# Processing Record 25 of Set 11 | tallahassee
# Processing Record 26 of Set 11 | berezovo
# Processing Record 27 of Set 11 | phek
# Processing Record 28 of Set 11 | bafq
# Processing Record 29 of Set 11 | geraldton
# Processing Record 30 of Set 11 | camiri
# Processing Record 31 of Set 11 | hobbs
# Processing Record 32 of Set 11 | bodaybo
# Processing Record 33 of Set 11 | nadvoitsy
# Processing Record 34 of Set 11 | sinop
# Processing Record 35 of Set 11 | zyryanskoye
# Processing Record 36 of Set 11 | necochea
# Processing Record 37 of Set 11 | dieppe
# Processing Record 38 of Set 11 | shangri-la
# City not found. Skipping...
# Processing Record 39 of Set 11 | kirakira
# Processing Record 40 of Set 11 | altai
# Processing Record 41 of Set 11 | dalai
# Processing Record 42 of Set 11 | basoko
# Processing Record 43 of Set 11 | mili
# Processing Record 44 of Set 11 | bastia
# Processing Record 45 of Set 11 | n'djamena
# Processing Record 46 of Set 11 | east ballina
# Processing Record 47 of Set 11 | vavoua
# Processing Record 48 of Set 11 | wildwood
# Processing Record 49 of Set 11 | along
# Processing Record 0 of Set 12 | ayancik
# Processing Record 1 of Set 12 | kenora
# Processing Record 2 of Set 12 | jabor
# Processing Record 3 of Set 12 | tekane
# City not found. Skipping...
# Processing Record 4 of Set 12 | jiagedaqi
# Processing Record 5 of Set 12 | novyy urengoy
# Processing Record 6 of Set 12 | zhezqazghan
# Processing Record 7 of Set 12 | nakamura
# Processing Record 8 of Set 12 | ancud
# Processing Record 9 of Set 12 | okhotsk
# Processing Record 10 of Set 12 | cascais
# Processing Record 11 of Set 12 | saint-francois
# Processing Record 12 of Set 12 | tazovsky
# Processing Record 13 of Set 12 | novodvinsk
# Processing Record 14 of Set 12 | paidha
# Processing Record 15 of Set 12 | kone
# Processing Record 16 of Set 12 | rey bouba
# Processing Record 17 of Set 12 | illizi
# Processing Record 18 of Set 12 | new richmond
# Processing Record 19 of Set 12 | polyarnyy
# Processing Record 20 of Set 12 | tanque verde
# Processing Record 21 of Set 12 | otofuke
# Processing Record 22 of Set 12 | vadso
# Processing Record 23 of Set 12 | mugumu
# Processing Record 24 of Set 12 | tyukhtet
# Processing Record 25 of Set 12 | newman
# Processing Record 26 of Set 12 | xylofagou
# Processing Record 27 of Set 12 | punta del este
# Processing Record 28 of Set 12 | nieuw amsterdam
# Processing Record 29 of Set 12 | shetpe
# Processing Record 30 of Set 12 | la jolla
# Processing Record 31 of Set 12 | morehead city
# Processing Record 32 of Set 12 | guayaramerin
# Processing Record 33 of Set 12 | zharkent
# Processing Record 34 of Set 12 | flin flon
# Processing Record 35 of Set 12 | sampit
# Processing Record 36 of Set 12 | maru
# Processing Record 37 of Set 12 | qarqaraly
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              lebu -37.6167  -73.6500     12.82        73          72
# 1    ribeira grande  38.5167  -28.7000     16.54        84          94
# 2           iqaluit  63.7506  -68.5145     -7.15        79         100
# 3         grytviken -54.2811  -36.5092      1.56        86          21
# 4            taunsa  30.7048   70.6505     32.82        30          10
# ..              ...      ...       ...       ...       ...         ...
# 557        zharkent  44.1628   80.0000     18.58        38          33
# 558       flin flon  54.7682 -101.8650     10.10        37         100
# 559          sampit  -2.5333  112.9500     30.06        66          96
# 560            maru  12.3342    6.4057     29.83        53          85
# 561       qarqaraly  49.4058   75.4742     15.49        34           6
#
#      Wind Speed Country        Date
# 0         11.00      CL  1684897040
# 1          4.02      PT  1684897056
# 2          2.57      CA  1684897040
# 3          5.68      GS  1684897035
# 4          4.24      PK  1684897146
# ..          ...     ...         ...
# 557        2.87      KZ  1684897299
# 558        4.32      CA  1684897299
# 559        1.65      ID  1684897299
# 560        4.89      NG  1684897299
# 561        3.78      KZ  1684897300
#
# [562 rows x 9 columns]

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0            lebu -37.6167 -73.6500     12.82        73          72
# 1  ribeira grande  38.5167 -28.7000     16.54        84          94
# 2         iqaluit  63.7506 -68.5145     -7.15        79         100
# 3       grytviken -54.2811 -36.5092      1.56        86          21
# 4          taunsa  30.7048  70.6505     32.82        30          10
#
#    Wind Speed Country        Date
# 0       11.00      CL  1684897040
# 1        4.02      PT  1684897056
# 2        2.57      CA  1684897040
# 3        5.68      GS  1684897035
# 4        4.24      PK  1684897146

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  lebu -37.6167 -73.6500     12.82        73          72
# 1        ribeira grande  38.5167 -28.7000     16.54        84          94
# 2               iqaluit  63.7506 -68.5145     -7.15        79         100
# 3             grytviken -54.2811 -36.5092      1.56        86          21
# 4                taunsa  30.7048  70.6505     32.82        30          10
#
#          Wind Speed Country        Date
# City_ID
# 0             11.00      CL  1684897040
# 1              4.02      PT  1684897056
# 2              2.57      CA  1684897040
# 3              5.68      GS  1684897035
# 4              4.24      PK  1684897146

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], linewidths=1, marker="x",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("Latitude v. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], linewidths=1, marker="x",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("Latitude v. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], linewidths=1, marker="x",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("Latitude v. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], linewidths=1, marker="x",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("Latitude v. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create scatter plot and plot the regression line
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    
    # Annotate the text for the line equation
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {r_value}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere_df=city_data_df.loc[(city_data_df["Lat"]>=0)]

# Display sample data
northern_hemisphere_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        ribeira grande  38.5167  -28.7000     16.54        84          94
# 2               iqaluit  63.7506  -68.5145     -7.15        79         100
# 4                taunsa  30.7048   70.6505     32.82        30          10
# 5                 sitka  57.0531 -135.3300     10.94        71           0
# 7         pacific grove  36.6177 -121.9166     13.70        86          40
#
#          Wind Speed Country        Date
# City_ID
# 1              4.02      PT  1684897056
# 2              2.57      CA  1684897040
# 4              4.24      PK  1684897146
# 5              5.14      US  1684897039
# 7              5.66      US  1684897147

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemisphere_df=city_data_df.loc[(city_data_df["Lat"]<=0)]

# Display sample data
southern_hemisphere_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                               lebu -37.6167  -73.6500     12.82        73
# 3                          grytviken -54.2811  -36.5092      1.56        86
# 6                           waitangi -43.9535 -176.5597     12.12        86
# 8                            ushuaia -54.8000  -68.3000      2.81        93
# 10       edinburgh of the seven seas -37.0676  -12.3116     13.45        59
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                72       11.00      CL  1684897040
# 3                21        5.68      GS  1684897035
# 6                78        1.79      NZ  1684897032
# 8               100        8.75      AR  1684897006
# 10               91       10.44      SH  1684897033

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Max Temp"]

# Call the function
plot_linear_regression(x_values, y_values,
                          'Max Temp',(0, 0))
# Out:
# The r-value is: -0.7864522574971733

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Max Temp"]

# Call the function
plot_linear_regression(x_values, y_values,
                          'Max Temp',(0, 0))
# Out:
# The r-value is: 0.7720550896455983

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Humidity"]

# Call the function
plot_linear_regression(x_values, y_values,
                          'Humidity',(0, 0))
# Out:
# The r-value is: -0.04747567654156248

# %%
# Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Humidity"]

# Call the function
plot_linear_regression(x_values, y_values,
                          'Humidity',(0, 0))
# Out:
# The r-value is: 0.09192790583770759

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Cloudiness"]

# Call the function
plot_linear_regression(x_values, y_values,
                          'Cloudiness',(0, 0))
# Out:
# The r-value is: -7.436985292526838e-05

# %%
# Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Cloudiness"]

# Call the function
plot_linear_regression(x_values, y_values,
                          'Cloudiness',(0, 0))
# Out:
# The r-value is: 0.007713334392188875

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Wind Speed"]

# Call the function
plot_linear_regression(x_values, y_values,
                          'Wind Speed',(0, 0))
# Out:
# The r-value is: 0.15773671713047543

# %%
# Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Wind Speed"]

# Call the function
plot_linear_regression(x_values, y_values,
                          'Wind Speed',(0, 0))
# Out:
# The r-value is: -0.2569362256856174

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
