# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 7
#       4 import requests
#       6 # Import API key
# ----> 7 from api_keys import geoapify_key
#
# ImportError: cannot import name 'geoapify_key' from 'api_keys' (C:\Users\calei\OneDrive\Desktop\BC\Homework\python-api-challenge\WeatherPy\api_keys.py)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        0            lebu -37.6167 -73.6500     12.82        73          72
# 1        1  ribeira grande  38.5167 -28.7000     16.54        84          94
# 2        2         iqaluit  63.7506 -68.5145     -7.15        79         100
# 3        3       grytviken -54.2811 -36.5092      1.56        86          21
# 4        4          taunsa  30.7048  70.6505     32.82        30          10
#
#    Wind Speed Country        Date
# 0       11.00      CL  1684897040
# 1        4.02      PT  1684897056
# 2        2.57      CA  1684897040
# 3        5.68      GS  1684897035
# 4        4.24      PK  1684897146

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
#%%capture --no-display

# Configure the map plot
humidity_map=city_data_df.hvplot.points("Lng", "Lat", 
                                        geo=True, tiles="OSM",
                                        frame_height=900, frame_width=800, size="Humidity", color="City", alpha=.75,
                                        hover_cols=["City"])

# Display the map
humidity_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
cities_narrowed = city_data_df[(city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 21)
                                    & (city_data_df["Cloudiness"] ==0) & (city_data_df["Wind Speed"] >= 4.5)] 

# Drop any rows with null values
cities_narrowed.dropna()

# Display sample data
cities_narrowed
# Out:
#      City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 106      106   mount isa -20.7333  139.5000     25.87        29           0
# 154      154      chaman  30.9236   66.4512     25.75        25           0
# 237      237   crucecita -28.9500  -58.9833     21.78        84           0
# 264      264       eilat  29.5581   34.9482     24.91        41           0
# 341      341  blackwater -23.5833  148.8833     25.42        23           0
# 553      553      shetpe  44.1667   52.1167     22.81        47           0
#
#      Wind Speed Country        Date
# 106        5.14      AU  1684897159
# 154        5.37      PK  1684897179
# 237        4.67      AR  1684897037
# 264        5.14      IL  1684897212
# 341        6.00      AU  1684897241
# 553        5.97      KZ  1684897298

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df= cities_narrowed[["City", "Country","Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=""

# Display sample data
hotel_df
# Out:
# C:\Users\calei\AppData\Local\Temp\ipykernel_7208\2732212034.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"]=""
#                City Country      Lat       Lng  Humidity Hotel Name
# 0              lebu      CL -37.6167  -73.6500        73
# 1    ribeira grande      PT  38.5167  -28.7000        84
# 2           iqaluit      CA  63.7506  -68.5145        79
# 3         grytviken      GS -54.2811  -36.5092        86
# 4            taunsa      PK  30.7048   70.6505        30
# ..              ...     ...      ...       ...       ...        ...
# 557        zharkent      KZ  44.1628   80.0000        38
# 558       flin flon      CA  54.7682 -101.8650        37
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit=100
params = { "categories": "accommodation.hotel","limit": limit,
          "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat=row["Lat"]
    lon=row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# lebu - nearest hotel: No hotel found
# ribeira grande - nearest hotel: No hotel found
# iqaluit - nearest hotel: No hotel found
# grytviken - nearest hotel: No hotel found
# taunsa - nearest hotel: No hotel found
# sitka - nearest hotel: No hotel found
# waitangi - nearest hotel: No hotel found
# pacific grove - nearest hotel: No hotel found
# ushuaia - nearest hotel: No hotel found
# bilibino - nearest hotel: No hotel found
# edinburgh of the seven seas - nearest hotel: No hotel found
# quatre cocos - nearest hotel: No hotel found
# avarua - nearest hotel: No hotel found
# kudahuvadhoo - nearest hotel: No hotel found
# longyearbyen - nearest hotel: No hotel found
# lihue - nearest hotel: No hotel found
# isafjordur - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# whitehorse - nearest hotel: No hotel found
# queenstown - nearest hotel: No hotel found
# ust-nera - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
Nearest_map=hotel_df.hvplot.points("Lng", "Lat", geo=True, tiles="OSM", frame_width=800, frame_height=800,
                                   alpha=0.75, color="City", hover_cols=["Hotel Name", "Country"]
                                  )

# Display the map
Nearest_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
